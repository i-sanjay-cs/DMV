# %%
import pandas as pd

# %%
df = pd.read_csv('Bengaluru_House_Data.csv')

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13305        Built-up  Area  Ready To Move                Whitefield
# 13306  Super built-up  Area  Ready To Move             Richards Town
# 13307        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13308  Super built-up  Area         18-Jun           Padmanabhanagar
# 13309  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df.columns = [column.title() for column in df.columns]

# %%
df.columns
# Out:
# Index(['Area_Type', 'Availability', 'Location', 'Size', 'Society',
#        'Total_Sqft', 'Bath', 'Balcony', 'Price'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['Area_Type', 'Availability', 'Location', 'Size', 'Society',
#        'Total_Sqft', 'Bath', 'Balcony', 'Price'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Area_Type          0
# Availability       0
# Location           1
# Size              16
# Society         5499
# Total_Sqft         0
# Bath              73
# Balcony          609
# Price              0
# dtype: int64

# %%
df['Balcony'] = df.fillna(df['Balcony'].mean(),inplace=True)

# %%
import numpy as np

# %%
df['Size'] = df['Size'].replace({
    '4 Bedroom':'4 BHK',
    '5 Bedroom':'5 BHK',
})

# %%
df
# Out:
#                   Area_Type   Availability                  Location   Size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II  2 BHK
# 1                Plot  Area  Ready To Move          Chikka Tirupathi  4 BHK
# 2            Built-up  Area  Ready To Move               Uttarahalli  3 BHK
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli  3 BHK
# 4      Super built-up  Area  Ready To Move                  Kothanur  2 BHK
# ...                     ...            ...                       ...    ...
# 13305        Built-up  Area  Ready To Move                Whitefield  5 BHK
# 13306  Super built-up  Area  Ready To Move             Richards Town  4 BHK
# 13307        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar  2 BHK
# 13308  Super built-up  Area         18-Jun           Padmanabhanagar  4 BHK
# 13309  Super built-up  Area  Ready To Move              Doddathoguru  1 BHK
#
#         Society Total_Sqft  Bath Balcony   Price
# ...

# %%
condition1 = ((df['Size']=='2 BHK') & (df['Bath'].isna()))
condition2 = ((df['Size']=='4 BHK') & (df['Bath'].isna()))

# %%
df['Bath'] = np.where(condition1,2,np.where(condition2,4,df['Bath']))

# %%
df.isna().sum()
# Out:
# Area_Type           0
# Availability        0
# Location            0
# Size                0
# Society             0
# Total_Sqft          0
# Bath                0
# Balcony         13310
# Price               0
# dtype: int64

# %%
# Assuming 'df' is your DataFrame
condition = (df['Size'] == '2bhk') & (df['Balcony'].isna())
filtered_rows = df[condition]

# %%
condition.sum()
# Out:
# 0

# %%
df2 = pd.read_csv('house_data.csv')

# %%
df2
# Out:
#               area_type   availability               location       size  \
# 0        Built-up  Area  Ready To Move              Gottigere      2 BHK
# 1            Plot  Area  Ready To Move               Sarjapur  3 Bedroom
# 2  Super built-up  Area  Ready To Move            Mysore Road      2 BHK
# 3  Super built-up  Area  Ready To Move          Bisuvanahalli      3 BHK
# 4  Super built-up  Area  Ready To Move  Raja Rajeshwari Nagar      3 BHK
# 5  Super built-up  Area  Ready To Move  Ramakrishnappa Layout      3 BHK
# 6  Super built-up  Area  Ready To Move     Manayata Tech Park      2 BHK
# 7        Built-up  Area  Ready To Move                Kengeri      1 BHK
# 8  Super built-up  Area         19-Dec             Binny Pete      3 BHK
# 9            Plot  Area  Ready To Move            Thanisandra  4 Bedroom
#
#    society  total_sqft  bath  balcony  price
# 0      NaN        1100     2        2   40.0
# 1  Skityer        2250     3        2  148.0
# ...

# %%
df2.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df2.columns = [column.title() for column in df2.columns]

# %%
merge_df = df.merge(df2,on="Location",how="inner")

# %%
merge_df
# Out:
#               Area_Type_x Availability_x       Location     Size_x Society_x  \
# 0    Super built-up  Area  Ready To Move  Bisuvanahalli      3 BHK   Prityel
# 1    Super built-up  Area  Ready To Move  Bisuvanahalli      3 BHK  1.584127
# 2    Super built-up  Area  Ready To Move  Bisuvanahalli      3 BHK   Prityel
# 3          Built-up  Area  Ready To Move  Bisuvanahalli      3 BHK   Prityel
# 4    Super built-up  Area  Ready To Move  Bisuvanahalli      3 BHK   Prityel
# ..                    ...            ...            ...        ...       ...
# 730  Super built-up  Area         20-Dec     Binny Pete      3 BHK   Shestlo
# 731            Plot  Area         20-Dec     Binny Pete  3 Bedroom   Shestlo
# 732  Super built-up  Area         19-Dec     Binny Pete      4 BHK   Shestlo
# 733  Super built-up  Area         18-Mar     Binny Pete      3 BHK   Shestlo
# 734  Super built-up  Area         18-May     Binny Pete      3 BHK   Shestlo
#
# ...

# %%
subset_of_data = df[df['Location']=="Gottigere"]

# %%
subset_of_data
# Out:
#                   Area_Type   Availability   Location       Size   Society  \
# 570          Built-up  Area  Ready To Move  Gottigere      2 BHK  1.584127
# 596          Built-up  Area  Ready To Move  Gottigere      2 BHK   Drente
# 775    Super built-up  Area  Ready To Move  Gottigere      3 BHK   Sklls C
# 786    Super built-up  Area  Ready To Move  Gottigere      2 BHK   Krryll
# 1866             Plot  Area  Ready To Move  Gottigere  2 Bedroom  1.584127
# 1999   Super built-up  Area  Ready To Move  Gottigere      3 BHK  1.584127
# 2152         Built-up  Area  Ready To Move  Gottigere  8 Bedroom  1.584127
# 2380   Super built-up  Area  Ready To Move  Gottigere      3 BHK  1.584127
# 2505   Super built-up  Area  Ready To Move  Gottigere      2 BHK  1.584127
# 2564   Super built-up  Area  Ready To Move  Gottigere      2 BHK   M denGa
# 2856             Plot  Area  Ready To Move  Gottigere  1 Bedroom  1.584127
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Bath_new'] = le.fit_transform(df['Bath'])

# %%
df['Bath_new']
# Out:
# 0        2
# 1        5
# 2        2
# 3        3
# 4        2
#         ..
# 13305    4
# 13306    5
# 13307    2
# 13308    4
# 13309    0
# Name: Bath_new, Length: 13310, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
df_encoded = pd.get_dummies(df, columns=['Area_Type'], prefix=['Category'])

# %%
df_encoded
# Out:
#         Availability                  Location   Size   Society Total_Sqft  \
# 0             19-Dec  Electronic City Phase II  2 BHK   Coomee        1056
# 1      Ready To Move          Chikka Tirupathi  4 BHK   Theanmp       2600
# 2      Ready To Move               Uttarahalli  3 BHK  1.584127       1440
# 3      Ready To Move        Lingadheeranahalli  3 BHK   Soiewre       1521
# 4      Ready To Move                  Kothanur  2 BHK  1.584127       1200
# ...              ...                       ...    ...       ...        ...
# 13305  Ready To Move                Whitefield  5 BHK   ArsiaEx       3453
# 13306  Ready To Move             Richards Town  4 BHK  1.584127       3600
# 13307  Ready To Move     Raja Rajeshwari Nagar  2 BHK   Mahla T       1141
# 13308         18-Jun           Padmanabhanagar  4 BHK   SollyCl       4689
# 13309  Ready To Move              Doddathoguru  1 BHK  1.584127        550
#
#        Bath Balcony   Price  Bath_new  Category_Built-up  Area  \
# ...

# %%
group = df.groupby(['Availability','Location'])

# %%
data = group['Price'].mean()

# %%
data
# Out:
# Availability   Location
# 14-Jul         Kumbena Agrahara         43.71
# 14-Nov         Whitefield               43.71
# 15-Aug         Yelahanka                62.00
# 15-Dec         1st Block Jayanagar     130.00
# 15-Jun         Outer Ring Road East     97.00
#                                         ...
# Ready To Move  singapura paradise      140.00
#                t.c palya               160.00
#                tc.palya                 48.00
#                vinayakanagar           200.00
#                white field,kadugodi    275.00
# Name: Price, Length: 2378, dtype: float64

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df = df[df['Price'] <= 3500]

# %%
sns.boxplot(df)
# Out:
# <Axes: >
