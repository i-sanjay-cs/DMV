# %%
import pandas as pd

# %%
df = pd.read_csv('city_day.csv')

# %%
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
df.dtypes
# Out:
# City           object
# Date           object
# PM2.5         float64
# PM10          float64
# NO            float64
# NO2           float64
# NOx           float64
# NH3           float64
# CO            float64
# SO2           float64
# O3            float64
# Benzene       float64
# Toluene       float64
# Xylene        float64
# AQI           float64
# AQI_Bucket     object
# dtype: object

# %%
Date = df['Date']
AQI_values = df['AQI']
Pollutant_level = df[['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene']]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
plt.plot(Date,AQI_values,c='r')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(Date,Pollutant_level)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.bar(df['Date'], df['AQI'], label="AQI")
plt.xlabel("Date")
plt.ylabel("AQI")
plt.title("AQI Comparison Across Dates")
plt.legend()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.box()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df["PM2.5"], df['AQI'], label="PM2.5", alpha=0.5)
plt.scatter(df["PM10"], df[AQI_values], label="PM10", alpha=0.5)
plt.scatter(df["CO"], df[AQI_values], label="CO", alpha=0.5)
plt.xlabel("Pollutant Levels")
plt.ylabel("AQI")
plt.title("Scatter Plot of AQI vs Pollutant Levels")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 plt.scatter(df["PM2.5"], df[AQI_values], label="PM2.5", alpha=0.5)
#       3 plt.scatter(df["PM10"], df[AQI_values], label="PM10", alpha=0.5)
#       4 plt.scatter(df["CO"], df[AQI_values], label="CO", alpha=0.5)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
# ...
